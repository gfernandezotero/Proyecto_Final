# %%
import pandas as pd
from ydata_profiling import ProfileReport
import sqlite3

# %%
# Cargar tu dataset en un DataFrame de pandas
conn = sqlite3.connect('accidentes_usa.db')
cursor_obj = conn.cursor()
df = pd.read_sql_query("SELECT * FROM acc_usa_sel", conn)

# Cerrar la conexión
conn.close()


# Generar el informe de perfilado
profile = ProfileReport(df, title="Informe de Perfilado", explorative=True)

profile.to_notebook_iframe()


# Guardar el informe en un archivo HTML
#profile.to_file("informe_perfilado.html")
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-06 12:03:15.028403&quot;&gt;&lt;title&gt;Informe de Perfilado&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
